# %%
import matplotlib
import matplotlib.pyplot
import pandas

# %%
dataframe = pandas.read_csv("flightdata2.csv", sep=",", header="infer")

# %%
print(dataframe)
# Out:
#            time     alpha         eas    radaralt   verticalspeed   power  \
# 0      0.010086  2.987042  296.143235  530.861245             0.0     0.0
# 1      0.550367  2.987042  296.143235  530.861245             0.0     0.0
# 2      0.560380  2.987042  296.143235  530.861245             0.0     0.0
# 3      0.570381  2.987042  296.143235  530.861245             0.0     0.0
# 4      0.580384  2.987042  296.143235  530.861245             0.0     0.0
# ...         ...       ...         ...         ...             ...     ...
# 4221  42.857022  1.874781  317.935385    1.728528             0.0     0.0
# 4222  42.867024  1.874781  317.935385    1.728528             0.0     0.0
# 4223  42.877027  1.874781  317.935385    1.728528             0.0     0.0
# 4224  42.887031  1.874781  317.935385    1.728528             0.0     0.0
# 4225  42.897032  1.837097  317.887157    1.685826             0.0     0.0
#
#         pitch
# 0     0.060377
# 1     0.060377
# 2     0.060377
# ...

# %%
dataframe.plot(x="time", y="radaralt")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'radaralt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a7763b7d0534> in <module>
# ...

# %%
dataframe.plot()
